# %% [markdown]
# # Load Libraries

# %%
using SVDapprox
using PyPlot

# %% [markdown]
# # Function To run

# %%
@everywhere begin
### Runs the approximate SVD with a test matrix
function run_test(A::Union(AbstractMatrix,DArray),k::Integer)

   # Approximate SVD
   t0 = time()
   (Uk,Sk,Vk) = svd_approx(A,k)
   tA = time() - t0
   B = Uk*diagm(Sk)*Vk'

   # Compute the true SVD
   As = try 
         convert(Array, A)
       catch
         A   
       end 
   k = length(Sk)
   t0 = time()
   (U,S,V) = svd(As)
   tB = time() - t0

   ### Error Analysis
   err_Approx = (normfro(As - B) / normfro(As))
   err_True   = (normfro(As - U[:,1:k]*diagm(S[1:k])*V[:,1:k]') / normfro(As))
   per_Diff   = (abs(err_True-err_Approx)/err_True*100)
   #@printf("Rank Approximation:    %i/%i\n",k,length(S))
   #@printf("Approximate SVD error: %5.2f\n",err_Approx)
   #@printf("True error:            %5.2f\n",err_True)
   #@printf("Percent Difference:    %5.2f%%\n",per_Diff)

   ### Return the rank and percent difference
   return per_Diff

end
end

# %% [markdown]
# # Compute the Error

# %% [markdown]
# ### Parameters

# %%
### Specify the size of "A" and number of processors
Nx, Ny   = 300, 300 
ProcsUse = 4 
kUSE     = [2:2:100];

# %% [markdown]
# ### Warm-up

# %%
### Warmup on four processors
@printf("Warming Up\n\n")
if nprocs() > ProcsUse
   rmprocs(procs()[end-(nprocs()-ProcsUse-1):end])
else
   addprocs(ProcsUse-nprocs())
end
A = rand(Nx,Ny)
collect(svd_approx(rand(Nx,Ny),20,4));
collect(svd_approx(drand(Nx,Ny),20,4));
collect(run_test(rand(Nx,Ny),2));
# Out:
# Warming Up

# %% [markdown]
# ### Get Error

# %%
### Test
@printf("\nRand/Randn matrices (sharp/smooth eigenvalue dropoff)\n")
rand_error  = zeros(length(kUSE),1)
randn_error = zeros(length(kUSE),1)
i           = 1 
for k in kUSE
   @printf("   Iter %i/%i: k-rank = %i\n",i,length(kUSE),k)
   rand_error[i]  = run_test(rand(Nx,Ny),k);
   randn_error[i] = run_test(randn(Nx,Ny),k);
   i += 1
end
# Out:
# Rand/Randn matrices (sharp/smooth eigenvalue dropoff)
#    Iter
# 1/50: k-rank = 2
#    Iter 2
# /50: k-rank = 4
#    Iter 3
# /50: k-rank = 6
#    Iter 4
# /50: k-rank = 8
#    Iter 5
# /50: k-rank = 10
#    Iter 6
# /50: k-rank = 12
#    Iter 7
# /50: k-rank = 14
#    Iter 8
# /50: k-rank = 16
#    Iter 9
# /50: k-rank = 18
#    Iter 10
# /50: k-rank = 20
#    Iter 11
# /50: k-rank = 22
#    Iter 12
# /50: k-rank = 24
#    Iter 13
# /50: k-rank = 26
#    Iter 14
# /50: k-rank = 28
#    Iter 15
# /50: k-rank = 30
#    Iter 16
# /50: k-rank = 32
#    Iter 17
# /50: k-rank = 34
#    Iter 18
# /50: k-rank = 36
#    Iter 19
# /50: k-rank = 38
#    Iter 20
# /50: k-rank = 40
#    Iter 21
# /50: k-rank = 42
#    Iter 22
# /50: k-rank = 44
#    Iter 23
# /50: k-rank = 46
#    Iter 24
# /50: k-rank = 48
#    Iter 25
# /50: k-rank = 50
#    Iter 26
# /50: k-rank = 52
#    Iter 27
# /50: k-rank = 54
#    Iter 28
# /50: k-rank = 56
#    Iter 29
# /50: k-rank = 58
#    Iter 30
# /50: k-rank = 60
#    Iter 31
# /50: k-rank = 62
#    Iter 32
# /50: k-rank = 64
#    Iter 33
# /50: k-rank = 66
#    Iter 34
# /50: k-rank = 68
#    Iter 35
# /50: k-rank = 70
#    Iter 36
# /50: k-rank = 72
#    Iter 37
# /50: k-rank = 74
#    Iter 38
# /50: k-rank = 76
#    Iter 39
# /50: k-rank = 78
#    Iter 40
# /50: k-rank = 80
#    Iter 41
# /50: k-rank = 82
#    Iter 42
# /50: k-rank = 84
#    Iter 43
# /50: k-rank = 86
#    Iter 44
# /50: k-rank = 88
#    Iter 45
# /50: k-rank = 90
#    Iter 46
# /50: k-rank = 92
#    Iter 47
# /50: k-rank = 94
#    Iter 48
# /50: k-rank = 96
#    Iter 49
# /50: k-rank = 98
#    Iter 50
# /50: k-rank = 100

# %% [markdown]
# # Plot

# %% [markdown]
# ### Rand Matrix (sharp eigenvalue decay)

# %%
p1 = plot(kUSE,rand_error,"b-")
xlab = xlabel(L"Rank, $k$")
ylab = ylabel(L"Percent Error, $\left|\frac{\epsilon_T - \epsilon_A}{\epsilon_T}\right|\times\,100$")
setp(p1,"linewidth",4)
setp(xlab,"FontSize",20)
setp(ylab,"FontSize",20)
ylim(0,6)
savefig("rand_error.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1140135d0>)

# %%
(U,S,V) = svd(rand(Nx,Ny))
xvals = [1:maximum(kUSE)]
yvals = S[1:maximum(kUSE)]
p1 = plot(xvals,yvals,"bo-")
xlab = xlabel(L"$i$")
ylab = ylabel(L"$\sigma_i$")
setp(p1,"linewidth",4,"MarkerSize",6)
setp(xlab,"FontSize",20)
setp(ylab,"FontSize",20)
savefig("rand_svd.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1028df850>)

# %% [markdown]
# ### Randn Matrix (smooth eigenvalue decay)

# %%
p1 = plot(kUSE,randn_error,"b-")
xlab = xlabel(L"Rank, $k$")
ylab = ylabel(L"Percent Error, $\left|\frac{\epsilon_T - \epsilon_A}{\epsilon_T}\right|\times\,100$")
setp(p1,"linewidth",4)
setp(xlab,"FontSize",20)
setp(ylab,"FontSize",20)
ylim(0,6)
savefig("randn_error.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10298b7d0>)

# %%
(U,S,V) = svd(randn(Nx,Ny))
xvals = [1:maximum(kUSE)]
yvals = S[1:maximum(kUSE)]
p1 = plot(xvals,yvals,"bo-")
xlab = xlabel(L"$i$")
ylab = ylabel(L"$\sigma_i$")
setp(p1,"linewidth",4,"MarkerSize",6)
setp(xlab,"FontSize",20)
setp(ylab,"FontSize",20)
savefig("randn_svd.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1061cce90>)
